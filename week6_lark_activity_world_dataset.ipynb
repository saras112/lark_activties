# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as st

# %%
df = pd.read_excel('Dataset_w6.xlsx')

# %%
df.head()
# Out:
#                country          Region  Surface area (km2)  \
# 0          Afghanistan    SouthernAsia              652864
# 1              Albania  SouthernEurope               28748
# 2              Algeria  NorthernAfrica             2381741
# 3               Angola    MiddleAfrica             1246700
# 4  Antigua and Barbuda       Caribbean                 442
#
#    Population in thousands (2017)  GDP per capita (current US$)  \
# 0                           35530                         623.2
# 1                            2930                        3984.2
# 2                           41318                        4154.1
# 3                           29784                        4714.1
# 4                             102                       14764.5
#
#    Agricultural production index   International trade: Imports (million US$)
# 0                             125                                        3568
# ...

# %%
#renaming column names for ease
df.rename(columns = {'Surface area (km2)':'Surface_area','Population in thousands (2017)':'Population','GDP per capita (current US$)':'GDP','Agricultural production index ':'Agricultural_production_index','International trade: Imports (million US$)':'Int_trade_Imports'}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        196 non-null    object
#  1   Region                         196 non-null    object
#  2   Surface_area                   196 non-null    int64
#  3   Population                     196 non-null    int64
#  4   GDP                            196 non-null    float64
#  5   Agricultural_production_index  196 non-null    int64
#  6   Int_trade_Imports              196 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 10.8+ KB

# %%
df.describe()
# Out:
#        Surface_area    Population            GDP  \
# count  1.960000e+02  1.960000e+02     196.000000
# mean   6.787071e+05  3.796658e+04   13727.343367
# std    1.914200e+06  1.434228e+05   18995.593914
# min    2.600000e+01  5.000000e+00     144.500000
# 25%    2.084900e+04  1.462000e+03    1840.725000
# 50%    1.136275e+05  7.677500e+03    5463.450000
# 75%    5.077380e+05  2.624075e+04   15849.550000
# max    1.709825e+07  1.409517e+06  100160.800000
#
#        Agricultural production index   Int_trade_Imports
# count                      196.000000       1.960000e+02
# mean                       117.066327       7.996138e+04
# std                         25.521247       2.340416e+05
# min                         34.000000       1.200000e+01
# 25%                        102.000000       2.162500e+03
# 50%                        114.000000       8.255500e+03
# 75%                        133.250000       4.612275e+04
# max                        199.000000       2.249661e+06

# %%
#1.Find out how many countries are there in the dataset.
df['country'].count()
# Out:
# 196

# %%
#2. Examine the data by using visualizations.
sns.pairplot(df)

# %%
#finding corelations in data columns in matrix form 
select_data = df[['Surface_area','Population','GDP','Agricultural_production_index','Int_trade_Imports']]
select_data.corr()
#not seeing any good correlation as its less than 0.7
# Out:
#                                Surface_area  Population       GDP  \
# Surface_area                       1.000000    0.448362  0.064154
# Population                         0.448362    1.000000 -0.051922
# GDP                                0.064154   -0.051922  1.000000
# Agricultural_production_index      0.086247    0.121782 -0.236847
# Int_trade_Imports                  0.482636    0.532012  0.315931
#
#                                Agricultural_production_index  \
# Surface_area                                        0.086247
# Population                                          0.121782
# GDP                                                -0.236847
# Agricultural_production_index                       1.000000
# Int_trade_Imports                                  -0.079844
#
#                                Int_trade_Imports
# Surface_area                            0.482636
# Population                              0.532012
# GDP                                     0.315931
# ...

# %%
#Creating a bar chart between GDP and Region 

plt.figure(figsize=(8,8))
sns.barplot(x='GDP', y='Region', data = df)
# Out:
# <AxesSubplot:xlabel='GDP', ylabel='Region'>

# %%
#Creating a barplot between GDP and Country to get top countries by GDP
plt.figure(figsize=(32,8))
sns.barplot(x='country', y='GDP', data=df.nlargest(10,'GDP'))
# Out:
# <AxesSubplot:xlabel='country', ylabel='GDP'>

# %%
#Creating a barplot between Surface_area and Region 
plt.figure(figsize=(8,8))
sns.barplot(x='Surface_area', y='Region', data=df)
# Out:
# <AxesSubplot:xlabel='Surface_area', ylabel='Region'>

# %%
#Creating a barplot between Surface_area and Country to get top countries by surface area
plt.figure(figsize=(32,8))
sns.barplot(x='country', y='Surface_area', data=df.nlargest(10,'Surface_area'))
# Out:
# <AxesSubplot:xlabel='country', ylabel='Surface_area'>

# %%
#creating a barplot between international trade import and region
plt.figure(figsize=(8,8))
sns.barplot(x='Int_trade_Imports', y='Region', data=df)
# Out:
# <AxesSubplot:xlabel='Int_trade_Imports', ylabel='Region'>

# %%
#Creating a barplot between International Trade import and Country to get top countries by trade import
plt.figure(figsize=(32,8))
sns.barplot(x='country', y='Int_trade_Imports', data=df.nlargest(10,'Int_trade_Imports'))
# Out:
# <AxesSubplot:xlabel='country', ylabel='Int_trade_Imports'>

# %%
#Creating a barplot between Agricultural_production_index  and Country
#to get top countries by Agricultural production index
plt.figure(figsize=(32,8))
sns.barplot(x='country', y='Agricultural_production_index', data=df.nlargest(10,'Agricultural_production_index'))
# Out:
# <AxesSubplot:xlabel='country', ylabel='Agricultural_production_index'>

# %%
#Creating a barplot between Population  and Country to get top countries by population

plt.figure(figsize=(32,8))
sns.barplot(x='country', y='Population', data=df.nlargest(10,'Population'))
# Out:
# <AxesSubplot:xlabel='country', ylabel='Population'>

# %%
df['Region'].unique()
# Out:
# array(['SouthernAsia', 'SouthernEurope', 'NorthernAfrica', 'MiddleAfrica',
#        'Caribbean', 'SouthAmerica', 'WesternAsia', 'Oceania',
#        'WesternEurope', 'EasternEurope', 'CentralAmerica',
#        'WesternAfrica', 'NorthernAmerica', 'SouthernAfrica',
#        'South-easternAsia', 'EasternAfrica', 'EasternAsia', 'Polynesia',
#        'NorthernEurope', 'Melanesia', 'CentralAsia', 'Micronesia'],
#       dtype=object)

# %%
#3. Find out how many countries with respect to the region are available in the dataset
group = df.groupby((df['Region']))
group.count().country
# Out:
# Region
# Caribbean            16
# CentralAmerica        8
# CentralAsia           5
# EasternAfrica        17
# EasternAsia           7
# EasternEurope        10
# Melanesia             5
# Micronesia            4
# MiddleAfrica          9
# NorthernAfrica        5
# NorthernAmerica       4
# NorthernEurope       10
# Oceania               2
# Polynesia             5
# South-easternAsia    11
# SouthAmerica         12
# SouthernAfrica        5
# SouthernAsia          9
# SouthernEurope       12
# WesternAfrica        15
# WesternAsia          18
# WesternEurope         7
# Name: country, dtype: int64

# %%
#4.On average which region has the highest a. GDP b.Trade import 
mean_gdp = group.GDP.mean()
mean_gdp.nlargest(1)
# Out:
# Region
# NorthernAmerica    57659.0
# Name: GDP, dtype: float64

# %%
mean_IntTradeImport = group.Int_trade_Imports.mean()
mean_IntTradeImport.nlargest(1)
# Out:
# Region
# NorthernAmerica    663552.25
# Name: Int_trade_Imports, dtype: float64

# %%
#5.Find out which region has more consistent with respect to GDP per capita (current US$)
# Here we are trying to understand how close each region's GDP is to its mean. This is the standard deviation
#The Region with the lowest standard deviation will be more consistent 
group.GDP.std().nsmallest(1)
# Out:
# Region
# WesternAfrica    815.095399
# Name: GDP, dtype: float64
